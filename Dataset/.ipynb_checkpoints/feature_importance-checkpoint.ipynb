# %%
#https://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
pd_data = pd.read_csv('new_dataset.csv')

# %%
pd_data.shape
# Out:
# (447530, 37)

# %%
feature_list = []

for i in pd_data:
    feature_list.append(i)

# %%
X = pd_data.loc[:, feature_list[:-1]]
y = pd_data.loc[:, ['activity']]

# %% [markdown]
# # Tree Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
forest = ExtraTreesClassifier(n_estimators=250,random_state=0)

# %%
forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
# Out:
# E:\CSE99\envs\CSE499\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 20 (0.153283)
# 2. feature 0 (0.087287)
# 3. feature 1 (0.085212)
# 4. feature 9 (0.067567)
# 5. feature 21 (0.036598)
# 6. feature 27 (0.036238)
# 7. feature 31 (0.035192)
# 8. feature 34 (0.033122)
# 9. feature 2 (0.033049)
# 10. feature 8 (0.032816)
# 11. feature 7 (0.030573)
# 12. feature 35 (0.029719)
# 13. feature 28 (0.029281)
# 14. feature 25 (0.028826)
# 15. feature 5 (0.027868)
# 16. feature 26 (0.025596)
# 17. feature 6 (0.025360)
# 18. feature 3 (0.024540)
# 19. feature 19 (0.024345)
# 20. feature 15 (0.022527)
# 21. feature 10 (0.020804)
# 22. feature 12 (0.018367)
# 23. feature 16 (0.014125)
# 24. feature 30 (0.012814)
# 25. feature 32 (0.012642)
# 26. feature 11 (0.011888)
# 27. feature 17 (0.009199)
# 28. feature 24 (0.008485)
# 29. feature 23 (0.005135)
# 30. feature 33 (0.004333)
# 31. feature 14 (0.003428)
# 32. feature 4 (0.003270)
# 33. feature 29 (0.003085)
# 34. feature 22 (0.002901)
# 35. feature 18 (0.000526)
# 36. feature 13 (0.000000)

# %%
# Plot the feature importances of the forest
plt.figure(figsize=(20,10))
plt.title('Feature Impotances: Using ExtraTreesClassifier',y=-0.1,fontsize=20)
plt.bar(range(X.shape[1]), importances[indices],color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])

plt.savefig("ExtraTreesClassifier.png")
#plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators=50)

# %%
forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
# Out:
# E:\CSE99\envs\CSE499\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
# Print the feature ranking WHEN n_estimators=50
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 31 (0.166521)
# 2. feature 1 (0.116857)
# 3. feature 20 (0.085449)
# 4. feature 0 (0.076720)
# 5. feature 3 (0.045838)
# 6. feature 9 (0.043050)
# 7. feature 34 (0.041152)
# 8. feature 26 (0.038173)
# 9. feature 25 (0.036752)
# 10. feature 27 (0.030283)
# 11. feature 28 (0.027393)
# 12. feature 8 (0.024743)
# 13. feature 35 (0.024461)
# 14. feature 21 (0.024006)
# 15. feature 2 (0.022917)
# 16. feature 32 (0.022379)
# 17. feature 19 (0.020214)
# 18. feature 10 (0.017101)
# 19. feature 7 (0.015514)
# 20. feature 15 (0.014889)
# 21. feature 12 (0.014055)
# 22. feature 5 (0.013060)
# 23. feature 6 (0.012994)
# 24. feature 16 (0.012402)
# 25. feature 30 (0.011016)
# 26. feature 11 (0.010921)
# 27. feature 17 (0.010676)
# 28. feature 24 (0.005387)
# 29. feature 4 (0.003300)
# 30. feature 23 (0.003034)
# 31. feature 29 (0.002414)
# 32. feature 14 (0.002315)
# 33. feature 33 (0.002008)
# 34. feature 22 (0.001477)
# 35. feature 18 (0.000529)
# 36. feature 13 (0.000000)

# %%
# Print the feature ranking WHEN n_estimators=200
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 31 (0.166521)
# 2. feature 1 (0.116857)
# 3. feature 20 (0.085449)
# 4. feature 0 (0.076720)
# 5. feature 3 (0.045838)
# 6. feature 9 (0.043050)
# 7. feature 34 (0.041152)
# 8. feature 26 (0.038173)
# 9. feature 25 (0.036752)
# 10. feature 27 (0.030283)
# 11. feature 28 (0.027393)
# 12. feature 8 (0.024743)
# 13. feature 35 (0.024461)
# 14. feature 21 (0.024006)
# 15. feature 2 (0.022917)
# 16. feature 32 (0.022379)
# 17. feature 19 (0.020214)
# 18. feature 10 (0.017101)
# 19. feature 7 (0.015514)
# 20. feature 15 (0.014889)
# 21. feature 12 (0.014055)
# 22. feature 5 (0.013060)
# 23. feature 6 (0.012994)
# 24. feature 16 (0.012402)
# 25. feature 30 (0.011016)
# 26. feature 11 (0.010921)
# 27. feature 17 (0.010676)
# 28. feature 24 (0.005387)
# 29. feature 4 (0.003300)
# 30. feature 23 (0.003034)
# 31. feature 29 (0.002414)
# 32. feature 14 (0.002315)
# 33. feature 33 (0.002008)
# 34. feature 22 (0.001477)
# 35. feature 18 (0.000529)
# 36. feature 13 (0.000000)

# %%
# Plot the feature importances of the forest
plt.figure(figsize=(20,10))
plt.title('Feature Impotances: Using RandomForestClassifier',y=-0.1,fontsize=20)
plt.bar(range(X.shape[1]), importances[indices],color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])

plt.savefig("RandomForestClassifier.png")
#plt.show()

# %% [markdown]
# # L1-based

# %%
from sklearn.svm import LinearSVC

lsvc = LinearSVC(C=0.01, penalty="l1", dual=False)

# %%
lsvc.fit(X,y)

importances = lsvc.feature_importances_
std = np.std([tree.feature_importances_ for tree in lsvc.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
# Out:
# /Users/arifsuhan/miniconda/envs/nlp/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/arifsuhan/miniconda/envs/nlp/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-35ca4ad287d5> in <module>
#       1 lsvc.fit(X,y)
#       2
# ----> 3 importances = lsvc.feature_importances_
#       4 std = np.std([tree.feature_importances_ for tree in lsvc.estimators_],axis=0)
#       5 indices = np.argsort(importances)[::-1]
#
# AttributeError: 'LinearSVC' object has no attribute 'feature_importances_'

# %%
# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# %%
# Plot the feature importances of the forest
plt.figure(figsize=(20,10))
plt.title('Feature Impotances: Using LinearSVC',y=-0.1,fontsize=20)
plt.bar(range(X.shape[1]), importances[indices],color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])

plt.savefig("LinearSVC.png")
#plt.show()
